# %% [markdown]
# # Week 2 Lab Assignment: Exploring Business Problems with Data

# %% [markdown]
# ### Objective
# In this lab, you will explore a dataset related to a common business problem, create visualizations to better understand the data, and propose a data science solution to address the problem. This exercise will help you apply the concepts of data exploration and problem definition covered in this week’s lecture.

# %% [markdown]
# ### 1. Dataset Overview
# You will be working with a dataset related to retail sales. The dataset contains information about daily sales, product categories, store locations, and other relevant attributes.
#
# **Dataset Name:** `retail_sales.csv`
#
# **Attributes:**
# - `Date`: The date of the sale.
# - `Store`: The store where the sale occurred.
# - `Product_Category`: The category of the product sold.
# - `Sales_Amount`: The dollar amount of the sale.
# - `Units_Sold`: The number of units sold.
# - `Discount_Applied`: Whether a discount was applied (Yes/No).

# %% [markdown]
# ### 2. Data Exploration
# **Objective:** Gain a preliminary understanding of the dataset.
#
# **Tasks:**
# 1. **Load the Dataset:** Import the dataset into a Pandas DataFrame.
# 2. **Inspect the Data:** Use Pandas functions to inspect the first few rows, check for missing values, and understand the data types.
# 3. **Summary Statistics:** Generate summary statistics for numerical columns (`Sales_Amount`, `Units_Sold`).

# %%
# Import necessary packages
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('retail_sales.csv')

# Inspect the first few rows
print(df.head())

# Check for missing values
print(df.isnull().sum())

# Generate summary statistics
print(df.describe())
# Out:
#          Date    Store Product_Category  Sales_Amount  Units_Sold  \
# 0  2024-01-01  Store_A      Electronics         250.0           1
# 1  2024-01-01  Store_A         Clothing         100.0           2
# 2  2024-01-01  Store_B       Home_Goods         150.0           3
# 3  2024-01-02  Store_A      Electronics         300.0           2
# 4  2024-01-02  Store_B         Clothing         120.0           1
#
#   Discount_Applied
# 0              Yes
# 1               No
# 2               No
# 3              Yes
# 4               No
# Date                0
# Store               0
# Product_Category    0
# Sales_Amount        0
# Units_Sold          0
# Discount_Applied    0
# dtype: int64
#        Sales_Amount  Units_Sold
# count     21.000000   21.000000
# mean     190.952381    2.190476
# std       90.050251    0.980767
# min       70.000000    1.000000
# 25%      130.000000    1.000000
# 50%      170.000000    2.000000
# 75%      220.000000    3.000000
# ...

# %% [markdown]
# ### 3. Data Visualization
# **Objective:** Create visualizations to uncover patterns and insights.
#
# **Tasks:**
# 1. **Sales Over Time:** Create a line plot showing total sales over time.
# 2. **Sales by Store:** Create a bar chart comparing total sales across different stores.
# 3. **Product Category Analysis:** Create a pie chart showing the distribution of sales across different product categories.
# 4. **Impact of Discounts:** Use a boxplot to compare the sales amounts for transactions with and without discounts.

# %%
import matplotlib.pyplot as plt

# Sales over time
df.groupby('Date')['Sales_Amount'].sum().plot(kind='line', title='Total Sales Over Time')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# Sales by Store
df.groupby('Store')['Sales_Amount'].sum().plot(kind='bar', title='Total Sales by Store')
plt.xlabel('Store')
plt.ylabel('Total Sales')
plt.show()

# Product Category Analysis
df.groupby('Product_Category')['Sales_Amount'].sum().plot(kind='pie', autopct='%1.1f%%', title='Sales by Product Category')
plt.ylabel('')
plt.show()

# Impact of Discounts
df.boxplot(column='Sales_Amount', by='Discount_Applied')
plt.title('Sales Amount by Discount Applied')
plt.suptitle('')
plt.xlabel('Discount Applied')
plt.ylabel('Sales Amount')
plt.show()

# %% [markdown]
# ### 4. Problem Definition
# **Objective:** Identify a specific business problem that can be addressed using the dataset.
#
# **Task:** Based on your exploration and visualizations, define a business problem (e.g., optimizing discount strategies to maximize sales). Write a brief description of the problem and propose a data science solution (e.g., using predictive modeling to identify the best times to offer discounts).
#
# **Example Problem Statement:**
# "The store is offering discounts to increase sales, but it is unclear whether the discounts are effectively boosting revenue. The business problem is to determine the optimal discount strategy that maximizes total sales without significantly reducing profit margins. A potential data science solution could involve using predictive modeling to forecast the impact of different discount levels on future sales."

# %% [markdown]
# ### 5. Submission
# **Deliverables:**
# - Jupyter Notebook (.ipynb) with all code, visualizations, and problem statement.
# - A brief report (1-2 paragraphs) summarizing your findings and proposed solution.
#
# **Deadline:** Submit your completed notebook and report to the course portal by end of class.
